# %% [markdown]
# # Louvain Algorithm

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - 오른쪽 아래 예시를 보면 된다.
#
# ### - 1st Phase

# %% [markdown]
# 1. Input Graph
# 2. Partitioning : 빨간색, 초록색, 파란색으로 분류
# 3. 슈퍼 노드로 합체

# %% [markdown]
# ### - 2st Phase
# - First phase 반복

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - 밑에 예시로 설명

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - node i를 D에서 C로 이동시키면 어떻게 변할까 ?
#
# - 이를 계산하는 방법은 두 개이 항으로 나누는 것이다.
#
# - ![image.png](data:image/png;base64,...) : 노드 i를 D에서 꺼내면 모듈성이 어떻게 변하는가

# %% [markdown]
# - ![image.png](data:image/png;base64,...): 노드 i를 가져와서 새로운 커뮤니티 C에 넣으면 어떻게 변하는가

# %% [markdown]
# - 위에 두 개를 더하면 최종 Modularity가 나온다.
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - 아래는 어떻게 이 값이 나오는지 설명하는거임.
# - 이해가 어려워서 뺌

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - 결론적으로, 이렇게 계산이 된다는 것

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
